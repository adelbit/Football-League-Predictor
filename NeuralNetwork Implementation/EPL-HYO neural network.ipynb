# %%
import pandas as pd
import seaborn as sns
import math
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.layers import Dense
# Out:
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ### Importing the EPL dataset

# %%
data = pd.read_csv("EPL_Set.csv")

# %% [markdown]
# ### Data exploration to check for NaN values and fill them

# %%
data.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN  NaN
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN  NaN
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN  NaN
# 4  E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN  NaN
#
#     Season
# 0  1993-94
# 1  1993-94
# 2  1993-94
# 3  1993-94
# 4  1993-94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   object
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      8740 non-null   float64
#  8   HTAG      8740 non-null   float64
#  9   HTR       8740 non-null   object
#  10  Season    9664 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 830.6+ KB

# %% [markdown]
#  We find that the columns "HTHG", "HTAG" and "HTR" are incomplete and plot a heatmap of the dataset below to visualize them better.

# %%
sns.heatmap(data.isnull(),cmap="viridis",yticklabels=False,cbar=False)

# %% [markdown]
# We fill the "HTHG" and "HTAG" columns having NaN values with the mean value of the respective coloumns and then perform some data corrections to omit any abnormality.

# %%
data["HTHG"]=data["HTHG"].fillna(value=math.ceil(data["HTHG"].mean()))

# %%
data["HTAG"]=data["HTAG"].fillna(value=math.ceil(data["HTAG"].mean()))

# %%
def hthg(cols):
    HTHG=cols[0]
    FTHG=cols[1]
    if FTHG == 0:
        return 0
    else:
        return HTHG

# %%
def htag(cols):
    HTAG=cols[0]
    FTAG=cols[1]
    if FTAG == 0:
        return 0
    else:
        return HTAG

# %%
data["HTHG"]=data[["HTHG","FTHG"]].apply(hthg,axis=1)

# %%
data["HTAG"]=data[["HTAG","FTAG"]].apply(hthg,axis=1)

# %%
data.head(10)
# Out:
#   Div      Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  14/08/93           Arsenal        Coventry     0     3   A   0.0   1.0
# 1  E0  14/08/93       Aston Villa             QPR     4     1   H   1.0   1.0
# 2  E0  14/08/93           Chelsea       Blackburn     1     2   A   1.0   1.0
# 3  E0  14/08/93         Liverpool  Sheffield Weds     2     0   H   1.0   0.0
# 4  E0  14/08/93          Man City           Leeds     1     1   D   1.0   1.0
# 5  E0  14/08/93         Newcastle       Tottenham     0     1   A   0.0   1.0
# 6  E0  14/08/93            Oldham         Ipswich     0     3   A   0.0   1.0
# 7  E0  14/08/93  Sheffield United         Swindon     3     1   H   1.0   1.0
# 8  E0  14/08/93       Southampton         Everton     0     2   A   0.0   1.0
# 9  E0  14/08/93          West Ham       Wimbledon     0     2   A   0.0   1.0
#
#    HTR   Season
# 0  NaN  1993-94
# 1  NaN  1993-94
# 2  NaN  1993-94
# 3  NaN  1993-94
# 4  NaN  1993-94
# 5  NaN  1993-94
# 6  NaN  1993-94
# 7  NaN  1993-94
# 8  NaN  1993-94
# 9  NaN  1993-94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   object
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      9664 non-null   float64
#  8   HTAG      9664 non-null   float64
#  9   HTR       8740 non-null   object
#  10  Season    9664 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 830.6+ KB

# %%
sns.heatmap(data.isnull(),cmap="viridis",yticklabels=False,cbar=False)

# %% [markdown]
# We can see from above that only the "HTR" columns have NaN values now. We write a function for it and fill in the values instead of NaN using the "HTHG" and "HTAG" coloumns.

# %%
def htr(cols):
    HTR=cols[0]
    HTHG=cols[1]
    HTAG=cols[2]
    if pd.isnull(HTR):
        if HTHG>HTAG:
            return "H"
        elif HTAG>HTHG:
            return "A"
        else:
            return "D"
    else:
        return HTR

# %%
data["HTR"]=data[["HTR","HTHG","HTAG"]].apply(htr,axis=1)

# %%
data.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   0.0   1.0   A
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   1.0   1.0   D
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   1.0   1.0   D
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   1.0   0.0   H
# 4  E0  14/08/93     Man City           Leeds     1     1   D   1.0   1.0   D
#
#     Season
# 0  1993-94
# 1  1993-94
# 2  1993-94
# 3  1993-94
# 4  1993-94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   object
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      9664 non-null   float64
#  8   HTAG      9664 non-null   float64
#  9   HTR       9664 non-null   object
#  10  Season    9664 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 830.6+ KB

# %%
sns.heatmap(data.isnull(),cmap="viridis",yticklabels=False,cbar=False)

# %% [markdown]
# Now all NaN values in the dataset have been filled and we can proceed with our complete dataset.

# %% [markdown]
# #### Since we have a complete dataset, we need to convert the string entries to entries that can be accepted by the model.

# %% [markdown]
# We will first convert the "HTR" and "FTR" columns and produce dummies for them

# %% [markdown]
# HTR column conversion and column order re-adjustments.

# %%
b=pd.get_dummies(data["HTR"],prefix="HTR")
data=pd.concat([data,b],axis=1)

# %%
data.drop("HTR",axis=1,inplace=True)
m=data["Season"]
data.drop("Season",axis=1,inplace=True)
data.insert(12,"Season",m)

# %%
data.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   0.0   1.0
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   1.0   1.0
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   1.0   1.0
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   1.0   0.0
# 4  E0  14/08/93     Man City           Leeds     1     1   D   1.0   1.0
#
#    HTR_A  HTR_D  HTR_H   Season
# 0      1      0      0  1993-94
# 1      0      1      0  1993-94
# 2      0      1      0  1993-94
# 3      0      0      1  1993-94
# 4      0      1      0  1993-94

# %% [markdown]
# FTR column conversion and column reordering

# %% [markdown]
# Dropping columns deemed not necessary

# %%
data.drop("Div",axis=1,inplace=True)
data.drop("Date",axis=1,inplace=True)

# %% [markdown]
# Converting data type to int for better readabilty.

# %%
data["HTHG"]=data["HTHG"].astype(int)
data["HTAG"]=data["HTAG"].astype(int)

# %%
data.head()
# Out:
#       HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR_A  HTR_D  \
# 0      Arsenal        Coventry     0     3   A     0     1      1      0
# 1  Aston Villa             QPR     4     1   H     1     1      0      1
# 2      Chelsea       Blackburn     1     2   A     1     1      0      1
# 3    Liverpool  Sheffield Weds     2     0   H     1     0      0      0
# 4     Man City           Leeds     1     1   D     1     1      0      1
#
#    HTR_H   Season
# 0      0  1993-94
# 1      0  1993-94
# 2      0  1993-94
# 3      1  1993-94
# 4      0  1993-94

# %% [markdown]
# Converting "Season" column from object type to a suitable type that can be accepted by the model

# %%
new=[]
end=[]
for index in data["Season"]:
    new.append(index.split("-")[0])
    end.append(index.split("-")[1])

# %%
data["Season S_Year"]=new
data["Season E_Year"]=end
data.drop("Season",axis=1,inplace=True)

# %%
data["Season S_Year"]=data["Season S_Year"].astype(int)
data["Season E_Year"]=data["Season E_Year"].astype(int)

# %%
data.head()
# Out:
#       HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR_A  HTR_D  \
# 0      Arsenal        Coventry     0     3   A     0     1      1      0
# 1  Aston Villa             QPR     4     1   H     1     1      0      1
# 2      Chelsea       Blackburn     1     2   A     1     1      0      1
# 3    Liverpool  Sheffield Weds     2     0   H     1     0      0      0
# 4     Man City           Leeds     1     1   D     1     1      0      1
#
#    HTR_H  Season S_Year  Season E_Year
# 0      0           1993             94
# 1      0           1993             94
# 2      0           1993             94
# 3      1           1993             94
# 4      0           1993             94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HomeTeam       9664 non-null   object
#  1   AwayTeam       9664 non-null   object
#  2   FTHG           9664 non-null   int64
#  3   FTAG           9664 non-null   int64
#  4   FTR            9664 non-null   object
#  5   HTHG           9664 non-null   int32
#  6   HTAG           9664 non-null   int32
#  7   HTR_A          9664 non-null   uint8
#  8   HTR_D          9664 non-null   uint8
#  9   HTR_H          9664 non-null   uint8
#  10  Season S_Year  9664 non-null   int32
#  11  Season E_Year  9664 non-null   int32
# dtypes: int32(4), int64(2), object(3), uint8(3)
# memory usage: 556.9+ KB

# %%
X_all = data.drop(['FTR','Season S_Year','Season E_Year'],1)
Y_all=data.drop(['HomeTeam','AwayTeam','FTHG','FTAG','HTHG','HTAG','HTR_A','HTR_D','HTR_H','Season S_Year','Season E_Year'],1)

# %% [markdown]
# segregating data into Features(X) and Labels(Y)

# %%
Y_all
# Out:
#      FTR
# 0      A
# 1      H
# 2      A
# 3      H
# 4      D
# ...   ..
# 9659   H
# 9660   A
# 9661   A
# 9662   H
# 9663   H
#
# [9664 rows x 1 columns]

# %%
X_all
# Out:
#          HomeTeam        AwayTeam  FTHG  FTAG  HTHG  HTAG  HTR_A  HTR_D  HTR_H
# 0         Arsenal        Coventry     0     3     0     1      1      0      0
# 1     Aston Villa             QPR     4     1     1     1      0      1      0
# 2         Chelsea       Blackburn     1     2     1     1      0      1      0
# 3       Liverpool  Sheffield Weds     2     0     1     0      0      0      1
# 4        Man City           Leeds     1     1     1     1      0      1      0
# ...           ...             ...   ...   ...   ...   ...    ...    ...    ...
# 9659    Newcastle         Chelsea     3     0     1     0      0      0      1
# 9660  Southampton        Man City     0     1     0     0      0      1      0
# 9661      Swansea           Stoke     1     2     1     2      1      0      0
# 9662    Tottenham       Leicester     5     4     1     2      1      0      0
# 9663     West Ham         Everton     3     1     1     0      0      0      1
#
# [9664 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_all['HomeTeam'] = le.fit_transform(data.HomeTeam.values)
X_all['AwayTeam'] = le.fit_transform(data.AwayTeam.values)
Y_all['FTR'] = le.fit_transform(data.FTR.values)

# %% [markdown]
# As it is better to just pass numerical inputs, here we Change the categorical inputs to numerical inputs

# %%
X_all
# Out:
#       HomeTeam  AwayTeam  FTHG  FTAG  HTHG  HTAG  HTR_A  HTR_D  HTR_H
# 0            0        14     0     3     0     1      1      0      0
# 1            1        34     4     1     1     1      0      1      0
# 2           13         4     1     2     1     1      0      1      0
# 3           24        37     2     0     1     0      0      0      1
# 4           25        22     1     1     1     1      0      1      0
# ...        ...       ...   ...   ...   ...   ...    ...    ...    ...
# 9659        29        13     3     0     1     0      0      0      1
# 9660        38        25     0     1     0     0      0      1      0
# 9661        41        39     1     2     1     2      1      0      0
# 9662        43        23     5     4     1     2      1      0      0
# 9663        46        17     3     1     1     0      0      0      1
#
# [9664 rows x 9 columns]

# %%
Y_all
# Out:
#       FTR
# 0       0
# 1       2
# 2       0
# 3       2
# 4       1
# ...   ...
# 9659    2
# 9660    0
# 9661    0
# 9662    2
# 9663    2
#
# [9664 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

#Shuffle and split the dataset into training and testing set.
X_train, X_test, Y_train, Y_test = train_test_split(X_all, Y_all, 
                                                    test_size = 0.33,
                                                   random_state = 2,
                                                   stratify = Y_all)

# %% [markdown]
# Splitting into train,test data

# %%
X_train
# Out:
#       HomeTeam  AwayTeam  FTHG  FTAG  HTHG  HTAG  HTR_A  HTR_D  HTR_H
# 7816        20        46     1     0     1     0      0      0      1
# 1065        17        37     2     2     1     2      1      0      0
# 6403         3         4     2     1     1     0      0      0      1
# 7547        30        47     2     1     1     0      0      0      1
# 8484        23        29     3     0     2     0      0      0      1
# ...        ...       ...   ...   ...   ...   ...    ...    ...    ...
# 4950        40        28     0     3     0     2      1      0      0
# 2345        17         0     0     2     0     1      1      0      0
# 6899        39        45     1     1     0     0      0      1      0
# 8323        45        25     1     3     0     3      1      0      0
# 3179        29        38     1     1     1     0      0      0      1
#
# [6474 rows x 9 columns]

# %%
X_test
# Out:
#       HomeTeam  AwayTeam  FTHG  FTAG  HTHG  HTAG  HTR_A  HTR_D  HTR_H
# 5693         0         3     1     1     1     0      0      0      1
# 77           4        46     0     2     0     1      1      0      0
# 3457        18         4     2     0     1     0      0      0      1
# 8729        25        17     0     0     0     0      0      1      0
# 5299        43         1     2     1     0     0      0      1      0
# ...        ...       ...   ...   ...   ...   ...    ...    ...    ...
# 1101        24        26     2     0     1     0      0      0      1
# 7611        43        26     1     1     0     1      1      0      0
# 1508        29        22     3     0     1     0      0      0      1
# 7248        26        24     2     1     0     0      0      1      0
# 3305        21        46     2     3     0     1      1      0      0
#
# [3190 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)

X_test = scaler.transform(X_test)

# %% [markdown]
# StandardScaler standardizes a feature by subtracting the mean and then scaling to unit variance.

# %%
X = np.squeeze(np.asarray(X_train))
Y = np.squeeze(np.asarray(Y_train))
Y_test = np.squeeze(np.asarray(Y_test))
X_test= np.squeeze(np.asarray(X_test))

# %%
X
# Out:
# array([[-0.3057593 ,  1.48275559, -0.40670775, ..., -0.52695265,
#         -0.88375216,  1.38048726],
#        [-0.51239339,  0.85988792,  0.36071457, ...,  1.8977037 ,
#         -0.88375216, -0.72438191],
#        [-1.47668581, -1.4239602 ,  0.36071457, ..., -0.52695265,
#         -0.88375216,  1.38048726],
#        ...,
#        [ 1.00292327,  1.41354808, -0.40670775, ..., -0.52695265,
#          1.13153896, -0.72438191],
#        [ 1.41619145,  0.02939769, -0.40670775, ...,  1.8977037 ,
#         -0.88375216, -0.72438191],
#        [ 0.31414297,  0.92909544, -0.40670775, ..., -0.52695265,
#         -0.88375216,  1.38048726]])

# %%
Y
# Out:
# array([2, 1, 2, ..., 1, 0, 1])

# %%
Y_test
# Out:
# array([1, 0, 2, ..., 2, 2, 0])

# %%
X_test
# Out:
# array([[-1.6833199 , -1.49316772, -0.40670775, ..., -0.52695265,
#         -0.88375216,  1.38048726],
#        [-1.40780778,  1.48275559, -1.17413007, ...,  1.8977037 ,
#         -0.88375216, -0.72438191],
#        [-0.44351536, -1.4239602 ,  0.36071457, ..., -0.52695265,
#         -0.88375216,  1.38048726],
#        ...,
#        [ 0.31414297, -0.17822486,  1.12813688, ..., -0.52695265,
#         -0.88375216,  1.38048726],
#        [ 0.10750888, -0.03980982,  0.36071457, ..., -0.52695265,
#          1.13153896, -0.72438191],
#        [-0.23688127,  1.48275559,  0.36071457, ...,  1.8977037 ,
#         -0.88375216, -0.72438191]])

# %%
X.shape
# Out:
# (6474, 9)

# %%
m=X.shape[0]
m
# Out:
# 6474

# %%
model = keras.Sequential([
    keras.layers.Dense(9,input_shape=(9,)),  # input layer (1)
    keras.layers.Dense(9, activation=tf.nn.relu),#hidden layer(2)
     keras.layers.Dense(9, activation=tf.nn.relu),# hidden layer (3)
    keras.layers.Dense(3, activation=tf.nn.softmax) # output layer (4)
])
# Out:
# WARNING:tensorflow:From C:\Users\Binvant\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 6474/6474 [==============================] - 0s 71us/sample - loss: 0.8328 - acc: 0.6098
# Epoch 2/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 0.4648 - acc: 0.8245
# Epoch 3/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 0.1375 - acc: 0.9795
# Epoch 4/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 0.0221 - acc: 1.0000
# Epoch 5/100
# 6474/6474 [==============================] - 0s 41us/sample - loss: 0.0073 - acc: 1.0000
# Epoch 6/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 0.0035 - acc: 1.0000
# Epoch 7/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 0.0021 - acc: 1.0000
# Epoch 8/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 0.0014 - acc: 1.0000
# Epoch 9/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 9.4889e-04 - acc: 1.0000
# Epoch 10/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 6.9682e-04 - acc: 1.0000
# Epoch 11/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 5.2912e-04 - acc: 1.0000
# Epoch 12/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 4.1236e-04 - acc: 1.0000
# Epoch 13/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 3.2811e-04 - acc: 1.0000
# Epoch 14/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.6520e-04 - acc: 1.0000
# Epoch 15/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.1703e-04 - acc: 1.0000
# Epoch 16/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.7959e-04 - acc: 1.0000
# Epoch 17/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.4989e-04 - acc: 1.0000
# Epoch 18/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.2614e-04 - acc: 1.0000
# Epoch 19/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 1.0682e-04 - acc: 1.0000
# Epoch 20/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 9.0937e-05 - acc: 1.0000
# Epoch 21/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 7.7833e-05 - acc: 1.0000
# Epoch 22/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 6.6874e-05 - acc: 1.0000
# Epoch 23/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 5.7679e-05 - acc: 1.0000
# Epoch 24/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 4.9910e-05 - acc: 1.0000
# Epoch 25/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 4.3318e-05 - acc: 1.0000
# Epoch 26/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 3.7708e-05 - acc: 1.0000
# Epoch 27/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 3.2891e-05 - acc: 1.0000
# Epoch 28/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 2.8742e-05 - acc: 1.0000
# Epoch 29/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.5166e-05 - acc: 1.0000
# Epoch 30/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.2073e-05 - acc: 1.0000
# Epoch 31/100
# 6474/6474 [==============================] - 0s 39us/sample - loss: 1.9388e-05 - acc: 1.0000
# Epoch 32/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 1.7055e-05 - acc: 1.0000
# Epoch 33/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.5020e-05 - acc: 1.0000
# Epoch 34/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 1.3245e-05 - acc: 1.0000
# Epoch 35/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.1694e-05 - acc: 1.0000
# Epoch 36/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 1.0336e-05 - acc: 1.0000
# Epoch 37/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 9.1402e-06 - acc: 1.0000
# Epoch 38/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 8.0942e-06 - acc: 1.0000
# Epoch 39/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 7.1721e-06 - acc: 1.0000
# Epoch 40/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 6.3610e-06 - acc: 1.0000
# Epoch 41/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 5.6493e-06 - acc: 1.0000
# Epoch 42/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 5.0218e-06 - acc: 1.0000
# Epoch 43/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 4.4649e-06 - acc: 1.0000
# Epoch 44/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 3.9749e-06 - acc: 1.0000
# Epoch 45/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 3.5402e-06 - acc: 1.0000
# Epoch 46/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 3.1576e-06 - acc: 1.0000
# Epoch 47/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 2.8182e-06 - acc: 1.0000
# Epoch 48/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 2.5180e-06 - acc: 1.0000
# Epoch 49/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.2530e-06 - acc: 1.0000
# Epoch 50/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.0148e-06 - acc: 1.0000
# Epoch 51/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 1.8057e-06 - acc: 1.0000
# Epoch 52/100
# 6474/6474 [==============================] - 0s 43us/sample - loss: 1.6198e-06 - acc: 1.0000
# Epoch 53/100
# 6474/6474 [==============================] - 0s 47us/sample - loss: 1.4551e-06 - acc: 1.0000
# Epoch 54/100
# 6474/6474 [==============================] - 0s 45us/sample - loss: 1.3094e-06 - acc: 1.0000
# Epoch 55/100
# 6474/6474 [==============================] - 0s 49us/sample - loss: 1.1782e-06 - acc: 1.0000
# Epoch 56/100
# 6474/6474 [==============================] - 0s 41us/sample - loss: 1.0632e-06 - acc: 1.0000
# Epoch 57/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 9.6305e-07 - acc: 1.0000
# Epoch 58/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 8.7214e-07 - acc: 1.0000
# Epoch 59/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 7.8941e-07 - acc: 1.0000
# Epoch 60/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 7.1518e-07 - acc: 1.0000
# Epoch 61/100
# 6474/6474 [==============================] - 0s 40us/sample - loss: 6.5059e-07 - acc: 1.0000
# Epoch 62/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 5.9816e-07 - acc: 1.0000
# Epoch 63/100
# 6474/6474 [==============================] - 0s 39us/sample - loss: 5.4804e-07 - acc: 1.0000
# Epoch 64/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 5.0370e-07 - acc: 1.0000
# Epoch 65/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 4.6572e-07 - acc: 1.0000
# Epoch 66/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 4.3397e-07 - acc: 1.0000
# Epoch 67/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 4.0569e-07 - acc: 1.0000
# Epoch 68/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 3.7676e-07 - acc: 1.0000
# Epoch 69/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 3.5164e-07 - acc: 1.0000
# Epoch 70/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 3.3109e-07 - acc: 1.0000
# Epoch 71/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 3.1469e-07 - acc: 1.0000
# Epoch 72/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 3.0108e-07 - acc: 1.0000
# Epoch 73/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.9169e-07 - acc: 1.0000
# Epoch 74/100
# 6474/6474 [==============================] - 0s 38us/sample - loss: 2.7887e-07 - acc: 1.0000
# Epoch 75/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.7119e-07 - acc: 1.0000
# Epoch 76/100
# 6474/6474 [==============================] - 0s 35us/sample - loss: 2.6643e-07 - acc: 1.0000
# Epoch 77/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.6245e-07 - acc: 1.0000
# Epoch 78/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.5744e-07 - acc: 1.0000
# Epoch 79/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.5158e-07 - acc: 1.0000
# Epoch 80/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.4978e-07 - acc: 1.0000
# Epoch 81/100
# 6474/6474 [==============================] - 0s 36us/sample - loss: 2.4888e-07 - acc: 1.0000
# Epoch 82/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.4709e-07 - acc: 1.0000
# Epoch 83/100
# 6474/6474 [==============================] - 0s 33us/sample - loss: 2.4473e-07 - acc: 1.0000
# Epoch 84/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.4319e-07 - acc: 1.0000
# Epoch 85/100
# 6474/6474 [==============================] - 0s 41us/sample - loss: 2.4225e-07 - acc: 1.0000
# Epoch 86/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.4138e-07 - acc: 1.0000
# Epoch 87/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.4120e-07 - acc: 1.0000
# Epoch 88/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.4100e-07 - acc: 1.0000
# Epoch 89/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.4059e-07 - acc: 1.0000
# Epoch 90/100
# 6474/6474 [==============================] - 0s 33us/sample - loss: 2.3969e-07 - acc: 1.0000
# Epoch 91/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.3947e-07 - acc: 1.0000
# Epoch 92/100
# 6474/6474 [==============================] - 0s 33us/sample - loss: 2.3938e-07 - acc: 1.0000
# Epoch 93/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.3923e-07 - acc: 1.0000
# Epoch 94/100
# 6474/6474 [==============================] - 0s 33us/sample - loss: 2.3906e-07 - acc: 1.0000
# Epoch 95/100
# 6474/6474 [==============================] - 0s 37us/sample - loss: 2.3884e-07 - acc: 1.0000
# Epoch 96/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.3875e-07 - acc: 1.0000
# Epoch 97/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.3873e-07 - acc: 1.0000
# Epoch 98/100
# 6474/6474 [==============================] - 0s 34us/sample - loss: 2.3871e-07 - acc: 1.0000
# Epoch 99/100
# 6474/6474 [==============================] - 0s 33us/sample - loss: 2.3866e-07 - acc: 1.0000
# Epoch 100/100
# 6474/6474 [==============================] - 0s 45us/sample - loss: 2.3866e-07 - acc: 1.0000

# %% [markdown]
# As seen above, the accuracy on first epoch was just 48% when the model was run for the first time but then it improved and by the 7th epoch we achieved 100% accuracy.

# %%
for layer in model.layers:
    weights = layer.get_weights()

# %%
weights
# Out:
# [array([[ 0.67975885,  0.703594  , -0.00347793],
#         [-0.27043024, -0.16951902,  0.44489557],
#         [-0.32414678, -1.0670581 ,  1.4189916 ],
#         [-1.2721932 ,  0.47532102, -0.9175502 ],
#         [ 1.3357767 ,  0.21850157, -0.16589448],
#         [-0.0756204 , -0.65575093,  0.8537327 ],
#         [-0.40968564, -0.24817066,  1.1715716 ],
#         [-1.4412344 ,  1.2871524 , -0.58691853],
#         [-1.1845603 , -0.0143405 ,  0.12584348]], dtype=float32),
#  array([ 0.04488296,  0.2495184 , -0.29438916], dtype=float32)]

# %% [markdown]
# These are the weights of the different neuron connections, weights nearer to 0 indicate that changing output do not affect the output

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('test_acc:', test_acc, 'test_loss', test_loss)
# Out:
# 3190/3190 [==============================] - 0s 22us/sample - loss: 2.3905e-07 - acc: 1.0000
# test_acc: 1.0 test_loss 2.390538348228038e-07

# %% [markdown]
#  The accuracy(100 %) and Test loss results are shown above

# %%
prediction=model.predict_classes(X_test[:])

# %% [markdown]
# Here we try to see our predicted results.

# %%
print(prediction)
# Out:
# [1 0 2 ... 2 2 0]

# %% [markdown]
# Here we can see that when model.predict() is passed the input features from X_test, It is able to accurately predict the labels in Y_test as shown below
# Where,
# #1 represents a draw
# #2 represents Home team win;
# #0 represents Away team win;

# %%
print(Y_test)
# Out:
# [1 0 2 ... 2 2 0]
